# %% [markdown]
# ## Assignment: Image recognition
# - Alumno 1: Dakota Mellish
# - Alumno 2: Javier Arteaga
# - Alumno 3: Rodrigo Castanon
#
# The goals of the assignment are:
# * Develop proficiency in using Tensorflow/Keras for training Neural Nets (NNs).
# * Put into practice the acquired knowledge to optimize the parameters and architecture of a feedforward Neural Net (ffNN), in the context of an image recognition problem.
# * Put into practice NNs specially conceived for analysing images. Design and optimize the parameters of a Convolutional Neural Net (CNN) to deal with previous task.
# * Train popular architectures from scratch (e.g., GoogLeNet, VGG, ResNet, ...), and compare the results with the ones provided by their pre-trained versions using transfer learning.
#
# Follow the link below to download the classification data set  “xview_recognition”: [https://drive.upm.es/s/4oNHlRFEd71HXp4](https://drive.upm.es/s/4oNHlRFEd71HXp4)

# %%
     
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Set Working Directory

# %%
import os 

print(os.getcwd())

os.chdir('/kaggle')
print(os.getcwd())


base_dir='/kaggle/input/xview-recognition/xview_recognition/'
# Out:
# /kaggle/working
# /kaggle

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Cargo plane', 1: 'Helicopter', 2: 'Small car', 3: 'Bus', 4: 'Truck', 5: 'Motorboat', 6: 'Fishing vessel', 7: 'Dump truck', 8: 'Excavator', 9: 'Building', 10: 'Storage tank', 11: 'Shipping container'}

# %%
# !pip install rasterio
import warnings
import rasterio
import numpy as np

def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    src_raster = rasterio.open(base_dir+filename, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    return img
# Out:
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (25.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2025.1.31)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from rasterio) (3.2.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.24->rasterio) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.24->rasterio) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.24->rasterio) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.24->rasterio) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.24->rasterio) (2024.2.0)
# Downloading rasterio-1.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 85.1 MB/s eta 0:00:00:00:0100:01
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.4.3

# %% [markdown]
# #### Training
# Design and train a ffNN to deal with the “xview_recognition” classification task.

# %%
import json
# Load database
json_file = base_dir+'/xview_ann_train.json'
with open(json_file) as ifs:
    json_data = json.load(ifs)
ifs.close()

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    obj = GenericObject()
    obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
    obj.category = json_ann['category_id']
    # Resampling strategy to reduce training time
    counts[obj.category] += 1
    image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Cargo plane': 635, 'Helicopter': 70, 'Small car': 4290, 'Bus': 2155, 'Truck': 2746, 'Motorboat': 1069, 'Fishing vessel': 706, 'Dump truck': 1236, 'Excavator': 789, 'Building': 4689, 'Storage tank': 1469, 'Shipping container': 1523}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 19239
# Number of validation images: 2138

# %% [markdown]
# ### Model Create
# Design model structure and shape

# %%
# Load architecture
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, add,Dropout, Activation, Flatten,LeakyReLU

from tensorflow.keras import Input


from numpy import random

## By default, the number of neurons is the same as the number of categories
def make_model(n_layers_dense,n_neurons,categories,input_shape,activation_list=None,activation_type=None,random_activation=None):
    model = Sequential()  
    model.add(Flatten(input_shape=input_shape))
    ## Pull common activation types from https://faroit.com/keras-docs/1.2.2/activations/
    activation_types=['relu','sigmoid','softmax','tanh','softplus','softsign','sigmoid','linear']
    for layer in range(0,n_layers_dense):
     
        if random_activation is None:
            if layer==n_layers_dense-1:
                model.add(Activation(activation_list[layer]))
                model.add(Dense(len(categories)))
            else:
                model.add(Dense(n_neurons))
        elif random_activation==True:
            rand_activation_idx=random.randint(low=0,high=len(activation_types))
            model.add(Activation(activation_types[rand_activation_idx]))
        
            model.add(Dense(n_neurons))
            if layer==n_layers_dense-1:
                model.add(Activation(activation_types[rand_activation_idx]))
                model.add(Dense(len(categories)))
    model.add(Activation('softmax'))
    return model




model_1=make_model(n_layers_dense=3,n_neurons=len(categories),input_shape=(224,224,3),activation_list=['relu','tanh','sigmoid','relu','linear'],categories=categories)

model_2=make_model(n_layers_dense=5,n_neurons=200,input_shape=(224,224,3),activation_list=['relu','tanh','sigmoid','relu','linear'],categories=categories)


model_3=make_model(n_layers_dense=5,n_neurons=1000,input_shape=(224,224,3),activation_list=['relu','tanh','sigmoid','relu','linear'],categories=categories)

model_4=make_model(n_layers_dense=8,n_neurons=1000,input_shape=(224,224,3),activation_list=['relu','tanh','sigmoid','relu','linear','sigmoid','softsign','tanh'],categories=categories)


# model.summary()







### Here we can experiment with the architecture and try different amounts of layers

# print('Load model')
# model = Sequential()
# ## This part will never change due to the input structure
# model.add(Flatten(input_shape=(224, 224, 3)))

# ## Here we can experiment between 
# model.add(Activation('relu'))
# model.add(Dropout(0.2))
# model.add(Dense(len(categories)))
# model.add(Activation('softmax'))
# model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
from tensorflow.keras.optimizers import Adam, SGD, RMSprop

learning_rates=[1e-3,1e-2,1e-1]

# Learning rate is changed to 0.001
opt_1 = Adam(learning_rate=learning_rates[1], beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
opt_2 = Adam(learning_rate=learning_rates[1], beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
opt_3 = Adam(learning_rate=learning_rates[1], beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)
opt_4 = Adam(learning_rate=learning_rates[1], beta_1=0.9, beta_2=0.999, epsilon=1e-8, amsgrad=True, clipnorm=1.0)

opt_2=SGD(learning_rate=learning_rates[1])
opt_3=RMSprop(learning_rate=learning_rates[1])



model_1.compile(optimizer=opt_1, loss='categorical_crossentropy', metrics=['accuracy'])
model_2.compile(optimizer=opt_2, loss='categorical_crossentropy', metrics=['accuracy'])
model_3.compile(optimizer=opt_3, loss='categorical_crossentropy', metrics=['accuracy'])
model_4.compile(optimizer=opt_4, loss='categorical_crossentropy', metrics=['accuracy'])



## Here we can experiment with a different optimizer such as Momentum, SGD, or RMSPROP as well as learning rate

# %%
from tensorflow.keras.callbacks import TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# Callbacks
model_checkpoint_1 = ModelCheckpoint('/kaggle/working/model_1.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
model_checkpoint_2 = ModelCheckpoint('/kaggle/working/model_2.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
model_checkpoint_3 = ModelCheckpoint('/kaggle/working/model_3.keras', monitor='val_accuracy', verbose=1, save_best_only=True)
model_checkpoint_4 = ModelCheckpoint('/kaggle/working/model_4.keras', monitor='val_accuracy', verbose=1, save_best_only=True)

reduce_lr = ReduceLROnPlateau('val_accuracy', factor=0.1, patience=10, verbose=1)
early_stop = EarlyStopping('val_accuracy', patience=40, verbose=1)
terminate = TerminateOnNaN()
callbacks_1 = [model_checkpoint_1, reduce_lr, early_stop, terminate]
callbacks_2 = [model_checkpoint_2, reduce_lr, early_stop, terminate]
callbacks_3 = [model_checkpoint_3, reduce_lr, early_stop, terminate]
callbacks_4 = [model_checkpoint_4, reduce_lr, early_stop, terminate]

# %%
def generator_images(objs, batch_size, do_shuffle=False):
    while True:
        if do_shuffle:
            np.random.shuffle(objs)
        groups = [objs[i:i+batch_size] for i in range(0, len(objs), batch_size)]
        for group in groups:
            images, labels = [], []
            for (filename, obj) in group:
                # Load image
                images.append(load_geoimage(filename))
                probabilities = np.zeros(len(categories))
                probabilities[list(categories.values()).index(obj.category)] = 1
                labels.append(probabilities)
            images = np.array(images).astype(np.float32)
            labels = np.array(labels).astype(np.float32)
            yield images, labels

# %%
# Generate the list of objects from annotations
objs_train = [(ann.filename, obj) for ann in anns_train for obj in ann.objects]
objs_valid = [(ann.filename, obj) for ann in anns_valid for obj in ann.objects]
# Generators
batch_size = 16
train_generator = generator_images(objs_train, batch_size, do_shuffle=True)
valid_generator = generator_images(objs_valid, batch_size, do_shuffle=False)

# %%
import math
import numpy as np

print('Training model')
epochs = 20
train_steps = math.ceil(len(objs_train)/batch_size)
valid_steps = math.ceil(len(objs_valid)/batch_size)
h_1 = model_1.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks_1, verbose=1)
h_2= model_2.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks_2, verbose=1)
h_3=model_3.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks_3, verbose=1)
h_4=model_4.fit(train_generator, steps_per_epoch=train_steps, validation_data=valid_generator, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks_4, verbose=1)

# # Best validation model
# best_idx = int(np.argmax(h.history['val_accuracy']))
# best_value = np.max(h.history['val_accuracy'])
# print('Best validation model: epoch ' + str(best_idx+1), ' - val_accuracy ' + str(best_value))
# Out:
# Training model
# Epoch 1/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2110 - loss: 2.1982
# Epoch 1: val_accuracy improved from -inf to 0.23152, saving model to /kaggle/working/model_1.keras
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 105s 86ms/step - accuracy: 0.2110 - loss: 2.1982 - val_accuracy: 0.2315 - val_loss: 2.1899 - learning_rate: 0.0100
# Epoch 2/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.2199 - loss: 2.1995
# Epoch 2: val_accuracy did not improve from 0.23152
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 119s 99ms/step - accuracy: 0.2199 - loss: 2.1995 - val_accuracy: 0.2273 - val_loss: 2.2032 - learning_rate: 0.0100
# Epoch 3/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.2120 - loss: 2.2058
# Epoch 3: val_accuracy did not improve from 0.23152
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 137s 114ms/step - accuracy: 0.2120 - loss: 2.2058 - val_accuracy: 0.1993 - val_loss: 2.2141 - learning_rate: 0.0100
# Epoch 4/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.2158 - loss: 2.2099
# Epoch 4: val_accuracy did not improve from 0.23152
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 111s 93ms/step - accuracy: 0.2158 - loss: 2.2099 - val_accuracy: 0.2039 - val_loss: 2.1838 - learning_rate: 0.0100
# Epoch 5/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2179 - loss: 2.1876
# Epoch 5: val_accuracy did not improve from 0.23152
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 101s 84ms/step - accuracy: 0.2179 - loss: 2.1877 - val_accuracy: 0.2306 - val_loss: 2.1730 - learning_rate: 0.0100
# Epoch 6/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.2178 - loss: 2.1915
# Epoch 6: val_accuracy did not improve from 0.23152
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 101s 84ms/step - accuracy: 0.2178 - loss: 2.1915 - val_accuracy: 0.2306 - val_loss: 2.1811 - learning_rate: 0.0100
# Epoch 7/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.2111 - loss: 2.1978
# Epoch 7: val_accuracy did not improve from 0.23152
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 97s 81ms/step - accuracy: 0.2111 - loss: 2.1978 - val_accuracy: 0.2240 - val_loss: 2.1689 - learning_rate: 0.0100
# Epoch 8/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2188 - loss: 2.1947
# Epoch 8: val_accuracy improved from 0.23152 to 0.24415, saving model to /kaggle/working/model_1.keras
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 93s 77ms/step - accuracy: 0.2188 - loss: 2.1947 - val_accuracy: 0.2442 - val_loss: 2.1431 - learning_rate: 0.0100
# Epoch 9/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2441 - loss: 2.1428
# Epoch 9: val_accuracy did not improve from 0.24415
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 95s 79ms/step - accuracy: 0.2441 - loss: 2.1428 - val_accuracy: 0.2442 - val_loss: 2.1238 - learning_rate: 0.0100
# Epoch 10/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.2301 - loss: 2.2480
# Epoch 10: val_accuracy did not improve from 0.24415
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 95s 79ms/step - accuracy: 0.2301 - loss: 2.2480 - val_accuracy: 0.1960 - val_loss: 2.2053 - learning_rate: 0.0100
# Epoch 11/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.2100 - loss: 2.2184
# Epoch 11: val_accuracy improved from 0.24415 to 0.25585, saving model to /kaggle/working/model_1.keras
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 101s 84ms/step - accuracy: 0.2100 - loss: 2.2184 - val_accuracy: 0.2558 - val_loss: 2.1806 - learning_rate: 0.0100
# Epoch 12/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2615 - loss: 2.1789
# Epoch 12: val_accuracy did not improve from 0.25585
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 94s 78ms/step - accuracy: 0.2614 - loss: 2.1789 - val_accuracy: 0.2250 - val_loss: 2.2082 - learning_rate: 0.0100
# Epoch 13/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.2240 - loss: 2.2045
# Epoch 13: val_accuracy did not improve from 0.25585
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 95s 79ms/step - accuracy: 0.2240 - loss: 2.2045 - val_accuracy: 0.1993 - val_loss: 2.1891 - learning_rate: 0.0100
# Epoch 14/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.2113 - loss: 2.2171
# Epoch 14: val_accuracy did not improve from 0.25585
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 95s 79ms/step - accuracy: 0.2113 - loss: 2.2171 - val_accuracy: 0.2320 - val_loss: 2.1950 - learning_rate: 0.0100
# Epoch 15/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.2151 - loss: 2.2108
# Epoch 15: val_accuracy did not improve from 0.25585
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 96s 80ms/step - accuracy: 0.2151 - loss: 2.2107 - val_accuracy: 0.2320 - val_loss: 2.1982 - learning_rate: 0.0100
# Epoch 16/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2159 - loss: 2.1987
# Epoch 16: val_accuracy did not improve from 0.25585
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 95s 79ms/step - accuracy: 0.2159 - loss: 2.1987 - val_accuracy: 0.1988 - val_loss: 2.1993 - learning_rate: 0.0100
# Epoch 17/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.2115 - loss: 2.2132
# Epoch 17: val_accuracy did not improve from 0.25585
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 97s 81ms/step - accuracy: 0.2115 - loss: 2.2132 - val_accuracy: 0.2320 - val_loss: 2.1915 - learning_rate: 0.0100
# Epoch 18/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.2110 - loss: 2.2112
# Epoch 18: val_accuracy did not improve from 0.25585
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 97s 81ms/step - accuracy: 0.2110 - loss: 2.2112 - val_accuracy: 0.1988 - val_loss: 2.1860 - learning_rate: 0.0100
# Epoch 19/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2158 - loss: 2.2022
# Epoch 19: val_accuracy did not improve from 0.25585
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 94s 78ms/step - accuracy: 0.2158 - loss: 2.2022 - val_accuracy: 0.1993 - val_loss: 2.1972 - learning_rate: 0.0100
# Epoch 20/20
# 1202/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2097 - loss: 2.2147
# Epoch 20: val_accuracy did not improve from 0.25585
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 95s 79ms/step - accuracy: 0.2097 - loss: 2.2147 - val_accuracy: 0.1988 - val_loss: 2.2001 - learning_rate: 0.0100
# Epoch 1/20
#    3/1203 ━━━━━━━━━━━━━━━━━━━━ 57s 48ms/step - accuracy: 0.0938 - loss: 7701909715741132718080.0000Batch 3: Invalid loss, terminating training
#    4/1203 ━━━━━━━━━━━━━━━━━━━━ 1:08 57ms/step - accuracy: 0.0859 - loss: nan
# Epoch 1: val_accuracy improved from -inf to 0.07203, saving model to /kaggle/working/model_2.keras
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.0626 - loss: nan - val_accuracy: 0.0720 - val_loss: nan - learning_rate: 0.0100
# Epoch 1/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1170 - loss: 5254255104.0000
# Epoch 1: val_accuracy improved from -inf to 0.31291, saving model to /kaggle/working/model_3.keras
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 112s 91ms/step - accuracy: 0.1170 - loss: 5252245504.0000 - val_accuracy: 0.3129 - val_loss: 53166612.0000 - learning_rate: 0.0100
# Epoch 2/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1470 - loss: 2086061440.0000
# Epoch 2: val_accuracy did not improve from 0.31291
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 102s 84ms/step - accuracy: 0.1470 - loss: 2086234880.0000 - val_accuracy: 0.2039 - val_loss: 114927960.0000 - learning_rate: 0.0100
# Epoch 3/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.1653 - loss: 1990386176.0000
# Epoch 3: val_accuracy did not improve from 0.31291
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 101s 84ms/step - accuracy: 0.1653 - loss: 1990465792.0000 - val_accuracy: 0.2521 - val_loss: 161939456.0000 - learning_rate: 0.0100
# Epoch 4/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1724 - loss: 1901503360.0000
# Epoch 4: val_accuracy did not improve from 0.31291
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 101s 84ms/step - accuracy: 0.1724 - loss: 1901654016.0000 - val_accuracy: 0.2170 - val_loss: 71896832.0000 - learning_rate: 0.0100
# Epoch 5/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.1638 - loss: 2436159232.0000
# Epoch 5: val_accuracy did not improve from 0.31291
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 101s 84ms/step - accuracy: 0.1638 - loss: 2436048640.0000 - val_accuracy: 0.0547 - val_loss: 6241416192.0000 - learning_rate: 0.0100
# Epoch 6/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.1762 - loss: 2242469888.0000
# Epoch 6: val_accuracy did not improve from 0.31291
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 98s 81ms/step - accuracy: 0.1762 - loss: 2242444544.0000 - val_accuracy: 0.2853 - val_loss: 108911304.0000 - learning_rate: 0.0100
# Epoch 7/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.1725 - loss: 2332094976.0000
# Epoch 7: val_accuracy did not improve from 0.31291
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 93s 78ms/step - accuracy: 0.1725 - loss: 2332003840.0000 - val_accuracy: 0.0706 - val_loss: 889797120.0000 - learning_rate: 0.0100
# Epoch 8/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.1696 - loss: 2670364160.0000
# Epoch 8: val_accuracy improved from 0.31291 to 0.34939, saving model to /kaggle/working/model_3.keras
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 98s 81ms/step - accuracy: 0.1696 - loss: 2670212608.0000 - val_accuracy: 0.3494 - val_loss: 117422664.0000 - learning_rate: 0.0100
# Epoch 9/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1762 - loss: 2859422208.0000
# Epoch 9: val_accuracy did not improve from 0.34939
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 93s 77ms/step - accuracy: 0.1762 - loss: 2859034368.0000 - val_accuracy: 0.0547 - val_loss: 19812542464.0000 - learning_rate: 0.0100
# Epoch 10/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.1816 - loss: 2278914048.0000
# Epoch 10: val_accuracy did not improve from 0.34939
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 97s 81ms/step - accuracy: 0.1816 - loss: 2279015936.0000 - val_accuracy: 0.2502 - val_loss: 324318784.0000 - learning_rate: 0.0100
# Epoch 11/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1710 - loss: 2283437056.0000
# Epoch 11: val_accuracy did not improve from 0.34939
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 95s 79ms/step - accuracy: 0.1710 - loss: 2283588608.0000 - val_accuracy: 0.0201 - val_loss: 1626479616.0000 - learning_rate: 0.0100
# Epoch 12/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1841 - loss: 1913776256.0000
# Epoch 12: val_accuracy did not improve from 0.34939
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 95s 79ms/step - accuracy: 0.1841 - loss: 1913967488.0000 - val_accuracy: 0.2021 - val_loss: 110843232.0000 - learning_rate: 0.0100
# Epoch 13/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1785 - loss: 2681599232.0000
# Epoch 13: val_accuracy did not improve from 0.34939
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 95s 79ms/step - accuracy: 0.1785 - loss: 2681397504.0000 - val_accuracy: 0.1656 - val_loss: 136048112.0000 - learning_rate: 0.0100
# Epoch 14/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1846 - loss: 2386873856.0000
# Epoch 14: val_accuracy did not improve from 0.34939
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 95s 79ms/step - accuracy: 0.1846 - loss: 2386884608.0000 - val_accuracy: 0.1239 - val_loss: 11039038464.0000 - learning_rate: 0.0100
# Epoch 15/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1783 - loss: 2839546624.0000
# Epoch 15: val_accuracy did not improve from 0.34939
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 94s 78ms/step - accuracy: 0.1783 - loss: 2839347712.0000 - val_accuracy: 0.2802 - val_loss: 70382192.0000 - learning_rate: 0.0100
# Epoch 16/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1843 - loss: 2462618880.0000
# Epoch 16: val_accuracy did not improve from 0.34939
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 94s 78ms/step - accuracy: 0.1843 - loss: 2462676736.0000 - val_accuracy: 0.0365 - val_loss: 9244616704.0000 - learning_rate: 0.0100
# Epoch 17/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1884 - loss: 2263347712.0000
# Epoch 17: val_accuracy did not improve from 0.34939
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 94s 78ms/step - accuracy: 0.1884 - loss: 2263339008.0000 - val_accuracy: 0.1319 - val_loss: 116558968.0000 - learning_rate: 0.0100
# Epoch 18/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1844 - loss: 2599047680.0000
# Epoch 18: val_accuracy did not improve from 0.34939
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 93s 78ms/step - accuracy: 0.1844 - loss: 2599057664.0000 - val_accuracy: 0.3040 - val_loss: 100477000.0000 - learning_rate: 0.0100
# Epoch 19/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.3021 - loss: 19639720.0000
# Epoch 19: val_accuracy did not improve from 0.34939
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 94s 78ms/step - accuracy: 0.3021 - loss: 19631492.0000 - val_accuracy: 0.3213 - val_loss: 2525161.7500 - learning_rate: 1.0000e-03
# Epoch 20/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.2690 - loss: 2869344.7500
# Epoch 20: val_accuracy improved from 0.34939 to 0.35921, saving model to /kaggle/working/model_3.keras
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 101s 84ms/step - accuracy: 0.2691 - loss: 2868943.2500 - val_accuracy: 0.3592 - val_loss: 1139099.0000 - learning_rate: 1.0000e-03
# Epoch 1/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1443 - loss: 3.9568
# Epoch 1: val_accuracy improved from -inf to 0.21188, saving model to /kaggle/working/model_4.keras
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 116s 93ms/step - accuracy: 0.1443 - loss: 3.9568 - val_accuracy: 0.2119 - val_loss: 3.0670 - learning_rate: 0.0100
# Epoch 2/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.1438 - loss: 4.1196
# Epoch 2: val_accuracy did not improve from 0.21188
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 99s 83ms/step - accuracy: 0.1438 - loss: 4.1196 - val_accuracy: 0.0706 - val_loss: 3.8793 - learning_rate: 0.0100
# Epoch 3/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.1477 - loss: 4.0170
# Epoch 3: val_accuracy did not improve from 0.21188
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 100s 83ms/step - accuracy: 0.1477 - loss: 4.0171 - val_accuracy: 0.2119 - val_loss: 5.0507 - learning_rate: 0.0100
# Epoch 4/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.1594 - loss: 3.8807
# Epoch 4: val_accuracy did not improve from 0.21188
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 99s 82ms/step - accuracy: 0.1594 - loss: 3.8806 - val_accuracy: 0.0875 - val_loss: 3.5297 - learning_rate: 0.0100
# Epoch 5/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1530 - loss: 3.9519
# Epoch 5: val_accuracy did not improve from 0.21188
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 101s 84ms/step - accuracy: 0.1530 - loss: 3.9519 - val_accuracy: 0.1399 - val_loss: 4.4248 - learning_rate: 0.0100
# Epoch 6/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.1606 - loss: 3.8179
# Epoch 6: val_accuracy did not improve from 0.21188
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 96s 80ms/step - accuracy: 0.1606 - loss: 3.8180 - val_accuracy: 0.0706 - val_loss: 3.9547 - learning_rate: 0.0100
# Epoch 7/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.1612 - loss: 3.8178
# Epoch 7: val_accuracy improved from 0.21188 to 0.23199, saving model to /kaggle/working/model_4.keras
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 104s 87ms/step - accuracy: 0.1612 - loss: 3.8179 - val_accuracy: 0.2320 - val_loss: 3.8854 - learning_rate: 0.0100
# Epoch 8/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.1464 - loss: 3.7856
# Epoch 8: val_accuracy did not improve from 0.23199
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 85s 71ms/step - accuracy: 0.1464 - loss: 3.7857 - val_accuracy: 0.0879 - val_loss: 3.6087 - learning_rate: 0.0100
# Epoch 9/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1560 - loss: 3.7280
# Epoch 9: val_accuracy did not improve from 0.23199
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 93s 77ms/step - accuracy: 0.1560 - loss: 3.7280 - val_accuracy: 0.0879 - val_loss: 3.1134 - learning_rate: 0.0100
# Epoch 10/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1510 - loss: 3.9702
# Epoch 10: val_accuracy did not improve from 0.23199
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 94s 78ms/step - accuracy: 0.1510 - loss: 3.9702 - val_accuracy: 0.2119 - val_loss: 3.5669 - learning_rate: 0.0100
# Epoch 11/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1488 - loss: 3.8966
# Epoch 11: val_accuracy did not improve from 0.23199
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 94s 78ms/step - accuracy: 0.1488 - loss: 3.8967 - val_accuracy: 0.1399 - val_loss: 3.9504 - learning_rate: 0.0100
# Epoch 12/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1494 - loss: 3.8740
# Epoch 12: val_accuracy did not improve from 0.23199
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 95s 79ms/step - accuracy: 0.1494 - loss: 3.8740 - val_accuracy: 0.1183 - val_loss: 3.7489 - learning_rate: 0.0100
# Epoch 13/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1451 - loss: 3.9582
# Epoch 13: val_accuracy did not improve from 0.23199
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 94s 78ms/step - accuracy: 0.1452 - loss: 3.9582 - val_accuracy: 0.1183 - val_loss: 3.5997 - learning_rate: 0.0100
# Epoch 14/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1562 - loss: 3.8000
# Epoch 14: val_accuracy did not improve from 0.23199
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 93s 77ms/step - accuracy: 0.1562 - loss: 3.8000 - val_accuracy: 0.2320 - val_loss: 3.3336 - learning_rate: 0.0100
# Epoch 15/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1530 - loss: 3.7394
# Epoch 15: val_accuracy did not improve from 0.23199
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 94s 78ms/step - accuracy: 0.1530 - loss: 3.7394 - val_accuracy: 0.0879 - val_loss: 4.3409 - learning_rate: 0.0100
# Epoch 16/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1482 - loss: 3.9464
# Epoch 16: val_accuracy did not improve from 0.23199
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 93s 78ms/step - accuracy: 0.1482 - loss: 3.9463 - val_accuracy: 0.2320 - val_loss: 3.4401 - learning_rate: 0.0100
# Epoch 17/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.1628 - loss: 3.6232
# Epoch 17: val_accuracy did not improve from 0.23199
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 96s 80ms/step - accuracy: 0.1628 - loss: 3.6233 - val_accuracy: 0.0365 - val_loss: 4.6747 - learning_rate: 0.0100
# Epoch 18/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1893 - loss: 2.4488
# Epoch 18: val_accuracy did not improve from 0.23199
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 93s 78ms/step - accuracy: 0.1893 - loss: 2.4488 - val_accuracy: 0.2119 - val_loss: 2.2962 - learning_rate: 1.0000e-03
# Epoch 19/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.1958 - loss: 2.3461
# Epoch 19: val_accuracy did not improve from 0.23199
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 96s 80ms/step - accuracy: 0.1958 - loss: 2.3461 - val_accuracy: 0.0875 - val_loss: 2.3716 - learning_rate: 1.0000e-03
# Epoch 20/20
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.1917 - loss: 2.3393
# Epoch 20: val_accuracy did not improve from 0.23199
# 1203/1203 ━━━━━━━━━━━━━━━━━━━━ 94s 78ms/step - accuracy: 0.1917 - loss: 2.3393 - val_accuracy: 0.2320 - val_loss: 2.4351 - learning_rate: 1.0000e-03

# %% [markdown]
# #### Validation
# Compute validation metrics.

# %%
import matplotlib.pyplot as plt
import numpy as np

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=list(categories.values()), yticklabels=list(categories.values()), ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show(fig)

# %%
import numpy as np

counter=0
for a_model in [model_1,model_2,model_3,model_4]:
    model=a_model
    num=counter+1
    model.load_weights('/kaggle/working/model_'+str(num)+'.keras')
    y_true, y_pred = [], []
    for ann in anns_valid:
        # Load image
        image = load_geoimage(ann.filename)
        for obj_pred in ann.objects:
            # Generate prediction
            warped_image = np.expand_dims(image, 0)
            predictions = model.predict(warped_image, verbose=0)
            # Save prediction
            pred_category = list(categories.values())[np.argmax(predictions)]
            pred_score = np.max(predictions)
            y_true.append(obj_pred.category)
            y_pred.append(pred_category)
    from sklearn.metrics import confusion_matrix
    
    # Compute the confusion matrix
    cm = confusion_matrix(y_true, y_pred, labels=list(categories.values()))
    draw_confusion_matrix(cm, categories)

    import numpy as np
    
    # Compute the accuracy
    correct_samples_class = np.diag(cm).astype(float)
    total_samples_class = np.sum(cm, axis=1).astype(float)
    total_predicts_class = np.sum(cm, axis=0).astype(float)
    print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
    acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
    print('Mean Recall: %.3f%%' % (acc.mean() * 100))
    acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
    print('Mean Precision: %.3f%%' % (acc.mean() * 100))
    for idx in range(len(categories)):
        # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
        # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
        tp = cm[idx, idx]
        fp = sum(cm[:, idx]) - tp
        fn = sum(cm[idx, :]) - tp
        tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
        # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
        recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
        # Precision: proportion of predicted positive cases that were truly real positives.
        precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
        # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
        specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
        # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
        # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
        f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
        print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))
    
    import os
    import numpy as np
    
    anns = []
    for (dirpath, dirnames, filenames) in os.walk(base_dir+'xview_test'):
        for filename in filenames:
            image = GenericImage('xview_test/'+filename)
            image.tile = np.array([0, 0, 224, 224])
            obj = GenericObject()
            obj.bb = (0, 0, 224, 224)
            obj.category = dirpath[dirpath.rfind('/')+1:]
            image.add_object(obj)
            anns.append(image)
    print('Number of testing images: ' + str(len(anns)))
    
    import numpy as np
    
    model.load_weights('/kaggle/working/model_'+str(num)+'.keras')
    predictions_data = {"images": {}, "annotations": {}}
    for idx, ann in enumerate(anns):
        image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
        predictions_data["images"][idx] = image_data
        # Load image
        image = load_geoimage(ann.filename)
        for obj_pred in ann.objects:
            # Generate prediction
            warped_image = np.expand_dims(image, 0)
            predictions = model.predict(warped_image, verbose=0)
            # Save prediction
            pred_category = list(categories.values())[np.argmax(predictions)]
            pred_score = np.max(predictions)
            annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
            predictions_data["annotations"][idx] = annotation_data
    
    with open("/kaggle/working/prediction_model"+str(counter)+".json", "w") as outfile:
        json.dump(predictions_data, outfile)

    counter+=1
# Out:
# <ipython-input-21-39df9ea0fe34>:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))
# Mean Accuracy: 25.585%
# Mean Recall: 10.078%
# Mean Precision: 4.339%
# > Cargo plane: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Helicopter: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Small car: Recall: 69.524% Precision: 23.379% Specificity: 44.296% Dice: 34.991%
# > Bus: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Truck: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Motorboat: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Fishing vessel: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Dump truck: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Excavator: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Building: Recall: 51.411% Precision: 28.684% Specificity: 61.389% Dice: 36.823%
# > Storage tank: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Shipping container: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# Number of testing images: 2635
# <ipython-input-21-39df9ea0fe34>:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))
# Mean Accuracy: 3.181%
# Mean Recall: 8.333%
# Mean Precision: 0.265%
# > Cargo plane: Recall: 100.000% Precision: 3.181% Specificity: 0.000% Dice: 6.165%
# > Helicopter: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Small car: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Bus: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Truck: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Motorboat: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Fishing vessel: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Dump truck: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Excavator: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Building: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Storage tank: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Shipping container: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# Number of testing images: 2635
# <ipython-input-21-39df9ea0fe34>:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))
# Mean Accuracy: 35.921%
# Mean Recall: 22.825%
# Mean Precision: 23.210%
# > Cargo plane: Recall: 5.882% Precision: 25.000% Specificity: 99.420% Dice: 9.524%
# > Helicopter: Recall: 0.000% Precision: 0.000% Specificity: 99.813% Dice: 0.000%
# > Small car: Recall: 86.190% Precision: 41.136% Specificity: 69.849% Dice: 55.692%
# > Bus: Recall: 15.068% Precision: 25.385% Specificity: 94.945% Dice: 18.911%
# > Truck: Recall: 11.321% Precision: 18.293% Specificity: 92.846% Dice: 13.986%
# > Motorboat: Recall: 7.865% Precision: 9.459% Specificity: 96.730% Dice: 8.589%
# > Fishing vessel: Recall: 10.390% Precision: 9.524% Specificity: 96.312% Dice: 9.938%
# > Dump truck: Recall: 28.205% Precision: 23.741% Specificity: 94.755% Dice: 25.781%
# > Excavator: Recall: 53.846% Precision: 19.535% Specificity: 91.602% Dice: 28.669%
# > Building: Recall: 47.984% Precision: 64.499% Specificity: 92.022% Dice: 55.029%
# > Storage tank: Recall: 0.654% Precision: 25.000% Specificity: 99.849% Dice: 1.274%
# > Shipping container: Recall: 6.494% Precision: 16.949% Specificity: 97.530% Dice: 9.390%
# Number of testing images: 2635
# <ipython-input-21-39df9ea0fe34>:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))
# Mean Accuracy: 23.199%
# Mean Recall: 8.333%
# Mean Precision: 1.933%
# > Cargo plane: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Helicopter: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Small car: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Bus: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Truck: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Motorboat: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Fishing vessel: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Dump truck: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Excavator: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Building: Recall: 100.000% Precision: 23.199% Specificity: 0.000% Dice: 37.661%
# > Storage tank: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# > Shipping container: Recall: 0.000% Precision: 0.000% Specificity: 100.000% Dice: 0.000%
# Number of testing images: 2635

# %%
# import numpy as np

# # Compute the accuracy
# correct_samples_class = np.diag(cm).astype(float)
# total_samples_class = np.sum(cm, axis=1).astype(float)
# total_predicts_class = np.sum(cm, axis=0).astype(float)
# print('Mean Accuracy: %.3f%%' % (np.sum(correct_samples_class) / np.sum(total_samples_class) * 100))
# acc = correct_samples_class / np.maximum(total_samples_class, np.finfo(np.float64).eps)
# print('Mean Recall: %.3f%%' % (acc.mean() * 100))
# acc = correct_samples_class / np.maximum(total_predicts_class, np.finfo(np.float64).eps)
# print('Mean Precision: %.3f%%' % (acc.mean() * 100))
# for idx in range(len(categories)):
#     # True/False Positives (TP/FP) refer to the number of predicted positives that were correct/incorrect.
#     # True/False Negatives (TN/FN) refer to the number of predicted negatives that were correct/incorrect.
#     tp = cm[idx, idx]
#     fp = sum(cm[:, idx]) - tp
#     fn = sum(cm[idx, :]) - tp
#     tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
#     # True Positive Rate: proportion of real positive cases that were correctly predicted as positive.
#     recall = tp / np.maximum(tp+fn, np.finfo(np.float64).eps)
#     # Precision: proportion of predicted positive cases that were truly real positives.
#     precision = tp / np.maximum(tp+fp, np.finfo(np.float64).eps)
#     # True Negative Rate: proportion of real negative cases that were correctly predicted as negative.
#     specificity = tn / np.maximum(tn+fp, np.finfo(np.float64).eps)
#     # Dice coefficient refers to two times the intersection of two sets divided by the sum of their areas.
#     # Dice = 2 |A∩B| / (|A|+|B|) = 2 TP / (2 TP + FP + FN)
#     f1_score = 2 * ((precision * recall) / np.maximum(precision+recall, np.finfo(np.float64).eps))
#     print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (list(categories.values())[idx], recall*100, precision*100, specificity*100, f1_score*100))

# %% [markdown]
# #### Testing
# Try to improve the results provided in the competition.

# %%
# import os
# import numpy as np

# anns = []
# for (dirpath, dirnames, filenames) in os.walk(base_dir+'xview_test'):
#     for filename in filenames:
#         image = GenericImage('xview_test/'+filename)
#         image.tile = np.array([0, 0, 224, 224])
#         obj = GenericObject()
#         obj.bb = (0, 0, 224, 224)
#         obj.category = dirpath[dirpath.rfind('/')+1:]
#         image.add_object(obj)
#         anns.append(image)
# print('Number of testing images: ' + str(len(anns)))

# %%
# import numpy as np

# model.load_weights('/kaggle/working/model.keras')
# predictions_data = {"images": {}, "annotations": {}}
# for idx, ann in enumerate(anns):
#     image_data = {"image_id": ann.filename.split('/')[-1], "filename": ann.filename, "width": int(ann.tile[2]), "height": int(ann.tile[3])}
#     predictions_data["images"][idx] = image_data
#     # Load image
#     image = load_geoimage(ann.filename)
#     for obj_pred in ann.objects:
#         # Generate prediction
#         warped_image = np.expand_dims(image, 0)
#         predictions = model.predict(warped_image, verbose=0)
#         # Save prediction
#         pred_category = list(categories.values())[np.argmax(predictions)]
#         pred_score = np.max(predictions)
#         annotation_data = {"image_id": ann.filename.split('/')[-1], "category_id": pred_category, "bbox": [int(x) for x in obj_pred.bb]}
#         predictions_data["annotations"][idx] = annotation_data

# %%
# with open("/kaggle/working/prediction.json", "w") as outfile:
#     json.dump(predictions_data, outfile)

# %%
predictions_data
